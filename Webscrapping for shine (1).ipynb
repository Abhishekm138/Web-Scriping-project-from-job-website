# %%
# Scrape The Data From Shine

# %%
import pandas as pd
import numpy as np
import time
import requests
import selenium
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from bs4 import BeautifulSoup
import urllib3

# %%
def getUrl(key):
    key = key.replace(' ','-')
    temp = 'https://www.shine.com/job-search/{}-jobs'
    url = temp.format(key)
    return url

# %%
url = getUrl('python')
print(url)
# Out:
# https://www.shine.com/job-search/python-jobs

# %%
res = requests.get(url)
print(res)
# Out:
# <Response [200]>

# %%
# driver = webdriver.Chrome()
# driver.get(url)

# %%
soup = BeautifulSoup(res.content,'html.parser')
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
cards = soup.find_all('div', class_='jobCard_jobCard__jjUmu white-box-border jobCard')
num_cards = len(cards)
print(num_cards)
# Out:
# 19

# %%
card = cards[0]
card
# Out:
# <div class="jobCard_jobCard__jjUmu white-box-border jobCard" itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem"><div><meta content="https://www.shine.com/jobs/hiring-for-data-scientist-permanent/radhika-enterprises/14214942" itemprop="url"/><meta content="2" itemprop="position"/><div class="jobCard_jobCard_features__wJid6"><span class="">Hot</span><span>0 days ago</span></div><h2 itemprop="name"><a href="/jobs/hiring-for-data-scientist-permanent/radhika-enterprises/14214942">Hiring For Data Scientist</a></h2><div class="jobCard_jobCard_cName__mYnow"><span>RADHIKA  ENTERPRISES</span></div><div class="jobCard_jobCard_lists__fdnsc"><div class="jobCard_jobCard_lists_item__YxRkV jobCard_jobIcon__3FB1t">0 to 4 Yrs</div><div class="jobCard_jobCard_lists_item__YxRkV jobCard_locationIcon__zrWt2">Oman<div class="more_info ml-10"><span>+<!-- -->12</span><div class="more_info_text arrow-box down_arrow arrow-right" style="bottom:25px;right:-5px">Qatar, Patna, Bhubanesw
# ...

# %%
# Fetching job_name
job_name = card.find('a').text if card.find('a') else 'Not Mentioned'
print(job_name)
# Out:
# Hiring For Data Scientist

# %%
# Fetching company_location
company_name_element = card.find('div', 'jobCard_jobCard_cName__mYnow')
if company_name_element:
    company_name = company_name_element.text
else:
    company_name = 'Not Mentioned'
print(company_name)
# Out:
# RADHIKA  ENTERPRISES

# %%
# Fetching experience_required
card_element = card.find('div', 'jobCard_jobCard_lists_item__YxRkV jobCard_jobIcon__3FB1t')
if card_element:
    experience_required = card_element.text
else:
    experience_required = 'Not Mentioned'
print(experience_required)
# Out:
# 0 to 4 Yrs

# %%
# Fetching job_description
job_card = card.find('ul', 'jobCard_jobCard_jobDetail__jD82J')
if job_card:
    job_description = job_card.text
else:
    job_description = 'Not Mentioned'
print(job_description)
# Out:
# Regular99 Positions

# %%
# Fetching job_apply_url
card_link = card.find('a')
if card_link:
    job_apply_url = 'https://www.shine.com' + card_link['href']
else:
    job_apply_url = 'Not Mentioned'

print(job_apply_url)
# Out:
# https://www.shine.com/jobs/hiring-for-data-scientist-permanent/radhika-enterprises/14214942

# %%
def find_job(card):
    # Fetching job_name
    job_name = card.find('a').text if card.find('a') else 'Not Mentioned'
    
    # Fetching company_name
    company_name = card.find('div','jobCard_jobCard_cName__mYnow').text if card.find('div','jobCard_jobCard_cName__mYnow') else 'Not Mentioned'
   
    # Fetching company_location
    company_location = card.find('div','jobCard_jobCard_lists_item__YxRkV jobCard_locationIcon__zrWt2').text if card.find('div','jobCard_jobCard_lists_item__YxRkV jobCard_locationIcon__zrWt2') else 'Not Mentioned'
    
    # Fetching experience_required
    experience_required = card.find('div','jobCard_jobCard_lists_item__YxRkV jobCard_jobIcon__3FB1t').text if card.find('div','jobCard_jobCard_lists_item__YxRkV jobCard_jobIcon__3FB1t') else 'Not Mentioned'
    
    # Fetching job_description
    job_description = card.find('ul','jobCard_jobCard_jobDetail__jD82J').text if card.find('ul','jobCard_jobCard_jobDetail__jD82J') else 'Not Mentioned'
    
    # Fetching job_apply_url
    job_apply_url = 'https://www.shine.com' + card.find('a')['href'] if card.find('a') and 'href' in card.find('a') else 'Not Mentioned'
    
    all_job_detail = (job_name, company_name, company_location, experience_required, job_description, job_apply_url)
    return all_job_detail

# %%
all_jobs = []
for i in cards:
    temp = find_job(i)
    all_jobs.append(temp)

# %%
all_jobs[3]
# Out:
# ('Mega Walk-In Drive on 3rd Feb 2024 | Exciting Opportuni ...',
#  'OptiSol Business Solutions',
#  'Chennai+1Other Tamil Nadu',
#  '1 to 12 Yrs',
#  'Regular',
#  'Not Mentioned')

# %%
# saving this data to a csv file
col = ['job_name','company_name','company_location','experience_required','job_description','job_apply_url']
shine_jobs_data = pd.DataFrame(all_jobs,columns=col)
shine_jobs_data.to_csv(r'C:\Users\Abhishek\Desktop\shine_jobs_details.csv',encoding='utf-8')
